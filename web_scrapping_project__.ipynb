# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
url="https://www.flipkart.com/apple-iphone-14-pro-max-silver-1-tb/p/itm674918cf10f1d?pid=MOBGHWFHHURZWVKE&lid=LSTMOBGHWFHHURZWVKEAO46IE&marketplace=FLIPKART&q=iphone+14+pro+max&store=tyy%2F4io&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_ps&fm=neo%2Fmerchandising&iid=5db22fca-1198-4c80-bf3d-d530b3f5a44b.MOBGHWFHHURZWVKE.SEARCH&ppt=clp&ppn=mobile-phones-store&ssid=jnh7iiehm80000001667901838676&qH=37e37d60a349d989"

# %%
output=requests.get(url)

# %%
output.content

# %%
soup=bs(output.content,"html.parser")

# %%
formated=soup.prettify()

# %%
# why list
list(soup.children)
# Out:
# ['html',
# ...

# %%
title=soup.title

title.string
# Out:
# 'APPLE iPhone 14 Pro Max ( 1 GB Storage, 0 GB RAM ) Online at Best Price On Flipkart.com'

# %%
price=soup.find_all("div",class_="dyC4hf")

# %%
price
# Out:
# [<div class="dyC4hf"><div class="CEmiEU"><div class="_25b18c"><div class="_30jeq3 _16Jk6d">₹1,89,900</div></div></div><div class="_1V9q7_"><img class="_3ECE0V" id="price-info-icon" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/info-basic_6c1a38.svg"/></div></div>]

# %%
product_price=[]
for i in range(0,len(price)):
    product_price.append(price[i].get_text())
product_price
# Out:
# ['₹1,89,900']

# %% [raw]
# #rating=soup.find_all("div",class_="_3LWZlK _1BLPMq")
# #print(rating)

# %% [raw]
# #product_rating=[]
# for i in range(0,len(rating)):
#     product_rating.append(rating[i].get_text())
# product_rating

# %%
review=soup.find_all("p",class_="_2-N8zT")
review
# Out:
# [<p class="_2-N8zT">Terrific purchase</p>,
#  <p class="_2-N8zT">Great product</p>,
#  <p class="_2-N8zT">Very Good</p>,
#  <p class="_2-N8zT">Brilliant</p>,
#  <p class="_2-N8zT">Classy product</p>,
#  <p class="_2-N8zT">Mind-blowing purchase</p>,
#  <p class="_2-N8zT">Fabulous!</p>,
#  <p class="_2-N8zT">Terrific</p>,
#  <p class="_2-N8zT">Must buy!</p>,
#  <p class="_2-N8zT">Brilliant</p>]

# %%
product_review=[]
for i in range(0,len(review)):
    product_review.append(review[i].get_text())
product_review
# Out:
# ['Terrific purchase',
#  'Great product',
#  'Very Good',
#  'Brilliant',
#  'Classy product',
#  'Mind-blowing purchase',
#  'Fabulous!',
#  'Terrific',
#  'Must buy!',
#  'Brilliant']

# %%
likes=soup.find_all("div",class_="_27aTsS")
likes
# Out:
# [<div class="_27aTsS"><div class="_1LmwT9"><svg class="skCrcq" height="15" width="20" xmlns="http://www.w3.org/2000/svg"><path class="_1LIt4y" d="M9.58.006c-.41.043-.794.32-1.01.728-.277.557-2.334 4.693-2.74 5.1-.41.407-.944.6-1.544.6v8.572h7.5c.45 0 .835-.28 1.007-.665 0 0 2.207-6.234 2.207-6.834 0-.6-.47-1.072-1.07-1.072h-3.216c-.6 0-1.07-.535-1.07-1.07 0-.537.835-3.387 1.006-3.944.17-.557-.107-1.157-.664-1.35-.15-.043-.257-.086-.407-.064zM0 6.434v8.572h2.143V6.434H0z" fill="#fff" fill-rule="evenodd"></path></svg><span class="_3c3Px5">1724</span></div><div class="_1LmwT9 pkR4jH"><svg class="skCrcq pkR4jH" height="15" width="20" xmlns="http://www.w3.org/2000/svg"><path class="_1LIt4y" d="M9.58.006c-.41.043-.794.32-1.01.728-.277.557-2.334 4.693-2.74 5.1-.41.407-.944.6-1.544.6v8.572h7.5c.45 0 .835-.28 1.007-.665 0 0 2.207-6.234 2.207-6.834 0-.6-.47-1.072-1.07-1.072h-3.216c-.6 0-1.07-.535-1.07-1.07 0-.537.835-3.387 1.006-3.944.17-.557-.107-1.157-.664-1.35-.15-.043-.257-.086-.407-.064zM
# ...

# %%
product_likes=[]
for i in range(0,len(likes)):
    product_likes.append(likes[i].get_text())
product_likes
# Out:
# ['1724264',
#  '53574',
#  '136',
#  '5177638',
#  '24927',
#  '945137',
#  '59387',
#  '11713',
#  '11313',
#  '23935']

# %%
qna=soup.find_all("div",class_="_2n4XY2 _1d7nTU col")

# %%
qnaa=[]
for i in range(0,len(qna)):
    qnaa.append(qna[i].get_text())
qnaa
# Out:
# ['Questions and Answers']

# %%
question=soup.find_all("div",class_="_1xR0kG _3cziW5")

# %%
questions=[]
for i in range(0,len(question)):
    questions.append(question[i].get_text())
questions
# Out:
# ['Q:Samsung s20 vs apple 14pro max',
#  'Q:Does it have wireless charging feature',
#  "Q:Nokia's 3310 or iphone 14 pro max",
#  'Q:Samsung s22 ultra best or iPhone 14 pro Max I need a answer',
#  'Q:How many watt does it support in charging ?',
#  'Q:iOS vs Android which is powerful',
#  'Q:Does it contain headphones',
#  'Q:Which Adaptor Best For iPhone 14pro max',
#  'Q:Apple 14 pro vs Apple 14 pro max',
#  'Q:What is the best camera of feature samsung galaxy s22 ultra v/s apple iphone 14pro max']

# %%
customer=soup.find_all("span",class_="_2GEIK5")

# %%
customers_names=[]
for i in range(0,len(customer)):
    customers_names.append(customer[i].get_text)
customers_names
# Out:
# [<bound method PageElement.get_text of <span class="_2GEIK5">New world Order NWO</span>>,
#  <bound method PageElement.get_text of <span class="_2GEIK5">Shiv Kumar</span>>,
#  <bound method PageElement.get_text of <span class="_2GEIK5">Dr.Harikesh Singh</span>>,
#  <bound method PageElement.get_text of <span class="_2GEIK5">Flipkart Customer</span>>,
#  <bound method PageElement.get_text of <span class="_2GEIK5">Jeevan Batla</span>>,
#  <bound method PageElement.get_text of <span class="_2GEIK5">Karthik Varma</span>>,
#  <bound method PageElement.get_text of <span class="_2GEIK5">Abhishek Pushker</span>>,
#  <bound method PageElement.get_text of <span class="_2GEIK5">Rinky</span>>,
#  <bound method PageElement.get_text of <span class="_2GEIK5">Samrat Roy</span>>,
#  <bound method PageElement.get_text of <span class="_2GEIK5">Satyendra Swargiary</span>>]

# %%
import pandas as pd

# %%
df=pd.DataFrame()
df["customers_names"]=customer
df["questions"]=questions
df["product_likes"]=likes
df["product_review"]=review

# %%
df
# Out:
#          customers_names                                          questions  \
# 0  [New world Order NWO]                   Q:Samsung s20 vs apple 14pro max
# 1           [Shiv Kumar]           Q:Does it have wireless charging feature
# 2    [Dr.Harikesh Singh]                Q:Nokia's 3310 or iphone 14 pro max
# 3    [Flipkart Customer]  Q:Samsung s22 ultra best or iPhone 14 pro Max ...
# 4         [Jeevan Batla]      Q:How many watt does it support in charging ?
# 5        [Karthik Varma]                 Q:iOS vs Android which is powerful
# 6     [Abhishek Pushker]                       Q:Does it contain headphones
# 7                [Rinky]          Q:Which Adaptor Best For iPhone 14pro max
# 8           [Samrat Roy]                 Q:Apple 14 pro vs Apple 14 pro max
# 9  [Satyendra Swargiary]  Q:What is the best camera of feature samsung g...
#
#                                        product_likes           product_review
# ...
